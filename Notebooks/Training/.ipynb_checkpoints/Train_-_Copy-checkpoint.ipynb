# %%
import os
import numpy as np
import pandas as pd
import csv
from csv import reader
from csv import writer
from sklearn import tree
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import uniform, norm
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.feature_selection import SelectFromModel, SelectKBest, VarianceThreshold, chi2, f_classif, mutual_info_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingClassifier
import matplotlib.pyplot as plt
from XLB import *
from apyori import apriori

import warnings
warnings.filterwarnings('ignore')

# %%
# extract data from files
x_train, y_train = extract_data("FinalTrainingSet.csv")
x_val, y_val = extract_data("Validation Set.csv")

# scale data values
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)

# feature selection
num_features = 69
feat_sel = VarianceThreshold()
x_train = feat_sel.fit_transform(x_train)
# 28.57% 0.25
# feat_sel_2 = SelectFromModel(estimator=DecisionTreeClassifier(random_state=481516234))
# 38.10% 0.29
# feat_sel_2 = SelectFromModel(\
#                 estimator=RandomForestClassifier(n_estimators=100,\
#                                              random_state=481516234))
# 42.86% 0.36
#feat_sel_2 = SelectFromModel(\
                #estimator=LogisticRegression(random_state=481516234))
# 
# feat_sel_2 = SelectFromModel(\
#                 estimator=svm.LinearSVC(C=0.25, penalty="l1", dual=False,\
#                                     random_state=481516234))
# 
feat_sel_2 = SelectKBest(chi2,k=num_features)
x_train = feat_sel_2.fit_transform(x_train,y_train)
print(feat_sel_2.get_support())
x_val = feat_sel_2.transform(feat_sel.transform(x_val))
# print("After Variance Threshold Feature Selection:",x_train.shape)

rand_seed = 3454132

oversampler = SMOTE(sampling_strategy="not majority",random_state=rand_seed)
x_smote, y_smote = oversampler.fit_resample(x_train,y_train)
print(x_smote.shape,y_smote.shape)

oversampler = RandomOverSampler(sampling_strategy="not majority",random_state=rand_seed)
x_os, y_os = oversampler.fit_resample(x_train,y_train)
print(x_os.shape,y_os.shape)
# Out:
# [ True  True  True  True  True False False False False False False False
#   True False False False False False  True False False False  True False
#  False False  True False False False False False  True False False False
#   True False False False False False  True False False False  True False
#  False False  True False False False False False False  True False  True
#   True  True  True False False False  True  True  True False  True  True
#  False False  True  True  True False  True False False  True  True False
#  False  True  True False False False  True  True  True False  True  True
#  False False  True  True  True False  True False False False False False
#  False False  True False  True False  True False  True False  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True False  True  True
#  False]
# (750, 69) (750,)
# (750, 69) (750,)

# %%
#MOVING FEATURE HEADERS INTO A LIST
import csv


# IsCalm = []
# IsCheerful = []
# IsBravery = []
# IsFearful = []
# IsLove = []
# IsSad = []
# Theme_Number = []  


f = open("FinalTrainingSet.csv")
reader = csv.reader(f)
features = next(reader)
row = list(reader)

csv_temp = pd.read_csv("FinalTrainingSet.csv")
Theme_numbered = csv_temp['Theme(Numbered)'].tolist()
Theme_numbered = np.asarray(Theme_numbered) 

# print(Theme_numbered.shape)
x_train = np.append(x_train, Theme_numbered.reshape(Theme_numbered.shape[0], 1), axis=1)
print(x_train.shape)

# x_train = np.delete(x_train, 69, axis=1)

#Deleting everything except features from the dataset
features.remove("Row Labels")
features.remove("Theme")
features.remove("Theme(Numbered)")
# print(len(features))
#Retained features after selection
selected_feats = feat_sel_2.get_support(True)

for ind, ft in sorted(enumerate(features), reverse=True): 
    if ind not in selected_feats:
        del features[ind]  
        
# np.append(x_train, Theme_numbered)
features.append('Theme_numbered')

new_column = pd.DataFrame({'Theme_numbered': Theme_numbered}) 
csv_temp = csv_temp.merge(new_column, left_index = True, right_index = True)

column = csv_temp.Theme_numbered

# column1 = csv_temp.IsCheerful
# column2 = csv_temp.IsBravery
# column3 = csv_temp.IsFearful
# column4 = csv_temp.IsLove
# column5 = csv_temp.IsSad 


# print(column)
# print(column1)
# print(column2)
# print(column3)
# print(column4)
# print(column5)

# csv_temp.to_csv('asd.csv', index = False

print(features)
row_count = len(row)
f.close()
 
print(x_train.shape)    
#Printing modified list 
# print (features) 
# print (len(features))
# Out:
# (401, 70)
# ['Tempo', 'Arousal', 'IsMajor', 'IsMinor', 'IsDissonant', 'Derivative of Root Mean Square Overall Standard Deviation', 'Derivative of Running Mean of Root Mean Square Overall Standard Deviation', 'Derivative of Running Mean of Spectral Flux Overall Standard Deviation', 'Derivative of Running Mean of Spectral Variability Overall Standard Deviation', 'Derivative of Spectral Flux Overall Standard Deviation', 'Derivative of Spectral Variability Overall Standard Deviation', 'Derivative of Standard Deviation of Root Mean Square Overall Standard Deviation', 'Derivative of Standard Deviation of Spectral Flux Overall Standard Deviation', 'Derivative of Standard Deviation of Spectral Variability Overall Standard Deviation', 'Fraction Of Low Energy Windows Overall Average', 'Magnitude Spectrum Overall Average', 'Magnitude Spectrum Overall Standard Deviation', 'Power Spectrum Overall Average', 'Power Spectrum Overall Standard Deviation', 'Running Mean of Compactness Overall Standard Deviation', 'Running Mean of Fraction Of Low Energy Windows Overall Average', 'Running Mean of Fraction Of Low Energy Windows Overall Standard Deviation', 'Running Mean of Root Mean Square Overall Standard Deviation', 'Running Mean of Spectral Centroid Overall Average', 'Running Mean of Spectral Flux Overall Standard Deviation', 'Running Mean of Spectral Rolloff Point Overall Average', 'Running Mean of Spectral Rolloff Point Overall Standard Deviation', 'Running Mean of Spectral Variability Overall Standard Deviation', 'Spectral Centroid Overall Average', 'Spectral Centroid Overall Standard Deviation', 'Spectral Rolloff Point Overall Average', 'Spectral Rolloff Point Overall Standard Deviation', 'Standard Deviation of Compactness Overall Standard Deviation', 'Standard Deviation of Fraction Of Low Energy Windows Overall Average', 'Standard Deviation of Fraction Of Low Energy Windows Overall Standard Deviation', 'Standard Deviation of Root Mean Square Overall Standard Deviation', 'Standard Deviation of Spectral Centroid Overall Average', 'Standard Deviation of Spectral Flux Overall Standard Deviation', 'Standard Deviation of Spectral Rolloff Point Overall Average', 'Standard Deviation of Spectral Rolloff Point Overall Standard Deviation', 'Standard Deviation of Spectral Variability Overall Standard Deviation', 'Beat Histogram Overall Standard Deviation', 'Beat Sum Overall Standard Deviation', 'ConstantQ Overall Standard Deviation', 'Derivative of Beat Sum Overall Standard Deviation', 'Derivative of LPC Overall Standard Deviation', 'Derivative of Method of Moments Overall Average', 'Derivative of Method of Moments Overall Standard Deviation', 'Derivative of MFCC Overall Average', 'Derivative of MFCC Overall Standard Deviation', 'Derivative of Partial Based Spectral Centroid Overall Average', 'Derivative of Partial Based Spectral Centroid Overall Standard Deviation', 'Derivative of Partial Based Spectral Flux Overall Average', 'Derivative of Partial Based Spectral Flux Overall Standard Deviation', 'Derivative of Peak Based Spectral Smoothness Overall Average', 'Derivative of Peak Based Spectral Smoothness Overall Standard Deviation', 'Derivative of Relative Difference Function Overall Average', 'Derivative of Relative Difference Function Overall Standard Deviation', 'Derivative of Running Mean of Beat Sum Overall Average', 'Derivative of Running Mean of Beat Sum Overall Standard Deviation', 'Derivative of Running Mean of LPC Overall Average', 'Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average', 'Derivative of Running Mean of Method of Moments Overall Standard Deviation', 'Derivative of Running Mean of MFCC Overall Average', 'Derivative of Running Mean of MFCC Overall Standard Deviation', 'Derivative of Running Mean of Partial Based Spectral Centroid Overall Standard Deviation', 'Derivative of Running Mean of Partial Based Spectral Flux Overall Standard Deviation', 'Derivative of Running  ...
# (401, 70)

# %%
"""
This abstract class represents a custom machine learning model.
"""
class AbstractCustomModel:
    
    """
    This is the default constructor for this class.
 
    Parameters:
    params : dict - hyperparameters for the model
    """
    def __init__(self,params):
        self.params = params
 
    """
    This method trains the model on the given dataset
 
    Parameters:
    x_train : numpy.ndarray - training set data
    """
    def train(self,x_train,y_train=None):
        # TODO
        pass
 
    """
    This method evaluates the performance of the model on the given test set.
 
    Parameters:
    x_test : numpy.ndarray - test set data
 
    Returns:
    A floating point number which measures the performance of the model on the 
    test set.
    """
    def evaluate(self,x_test,y_test=None):
        # TODO
        pass

# %%
"""
This class is an adapter for the Apyori library.
"""
class APyoriAdapter(AbstractCustomModel):
 
    """
    This is the default constructor for this class.
 
    Parameters:
    params : dict - hyperparameters for the model
    """
    def __init__(self,params={}):
        self.params = params
        super().__init__(params)
 

    def convert_to_transaction(self,row):
        return [(i,j)for i,j in enumerate(row)]

    """
    This method trains the model on the given dataset
 
    Parameters:
    x_train : numpy.ndarray - training set data
    """
    def train(self,x_train,y_train=None):
        x_train = self.discretize_dataset(x_train,self.params["thresholds"])
        data_2 = [[i for i,j in enumerate(row) if j==1 ] for row in x_train]
        #if running takes long we raise min support 
        self.results = list(apriori(data_2,min_support=0.22))
    
 
    """
    This method evaluates the performance of the model on the given test set.
 
    Parameters:
    x_test : numpy.ndarray - test set data
 
    Returns:
    A floating point number which measures the performance of the model on the 
    test set.
    """
    def evaluate(self,x_test,y_test=None):
        # TODO
        pass
    
    
    """
    discretize_dataset function transforms the dataset into binary o

    Takes the input of:
    -data = 
    -thresholds = 
    """
    def discretize_dataset(self,data,thresholds):
        temp = [row[::]for row in data]
        data = temp
        for i, datapoint in enumerate(data):
            for j, threshold in enumerate(thresholds):
                if datapoint[j] >= threshold:
                    datapoint[j] = 1
                else: 
                    datapoint[j] = 0
        return data

# %%
featurelist = []

# %%
np.random.seed(69420)
model = APyoriAdapter({
    "thresholds" : np.random.normal(0.5, 0.15, num_features)
})

emotion_val = [1,2,3,4,5,6]
emotions = ["IsCalm", "IsCheerful", "IsBravery", "IsFearful", "IsLove", "IsSadness"]
lift_supp = [0.3117,  0.1372, 0.1397,  0.2469, 0.0673, 0.0973]
model.train(x_train)
targets = [list(range(70,75))]

#Counters
ctr = 0
three_Item_Set_ctr = 0
rules = 1
confcount = 0
list_features = []
totalconf= 0
avgconf = 0
conflist = []
minconf = 0
maxconf = 0


for ruleset in model.results:
#     if len(ruleset.items) >= 3:
#         three_Item_Set_ctr += 1
#         print("Got {} itemsets with three or more".format(three_Item_Set_ctr))
        
    ctr += 1
    print("LENGTH OF RULESET", len(ruleset.ordered_statistics))
    print("Got {} itemsets".format(ctr))
    print("THIS IS THE RULESET",ruleset)    
    for ord in ruleset.ordered_statistics:
        print("1st loop check")
        print("ITEMS BASE", len(ord.items_base))
        print("ITEMS add", len(ord.items_add))
        if len(ord.items_base) > 0 and len(ord.items_add) > 0:
            featurelist.clear()
            print("check")
            for i in ord.items_base:
                featurelist.append(features[i])
#                 print(len(featurelist))
                
        list_features = list(featurelist) 
        print("ruleset.ordered_statistics loop ends check")

        #list of indexes of the feature
    colno = []

    #this loops gets the indexes of the columns of the features
    for i in list_features:
        #this is to find which column sya
        colno.append(features.index(i))

    print("list features loop check")    


    #gets the column of the emotion
    emotioncol = 69

     #This loops through all emotions
    for k in emotion_val:
        #This loops through the whole 401
        confcount = 0
        for i in range(row_count):
            #This checks if all is true pa 
            s = True
            for j in colno:
                if(x_train[i][j] == 1 and x_train[i][emotioncol] == k and s == True):
                    s = True
                else:
                    s = False  

            #if all are true pa for that row meaning all the featurelist are 1 for that row, increment 
            if(s == True):
                confcount += 1




#         print(confcount)

#         totalconf = totalconf + confidence
        confidence = (confcount/row_count) / ruleset.support
        lift = confidence / lift_supp[emotion_val.index(k)]
#         conflist = np.append(conflist,confidence)


#         if(lift >= 1 and confidence >= 0.5):
        print("""Rule {} -> {} has
        support = {:.2f}
        confidence = {:.2f}
        lift = {:.2f}

        """.format(list(featurelist),emotions[k-1],ruleset.support,\
                    confidence,lift))

        print(rules)
        rules += 1

    print("final loop check")
# minconf = min(conflist)
# maxconf = max(conflist)
# avgconf = totalconf/ctr


# print(avgconf)
# print(minconf)
# print(maxconf)
# Out:
# LENGTH OF RULESET 1
# Got 1 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0}), support=0.6234413965087282, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0}), confidence=0.6234413965087282, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.62
#         confidence = 0.17
#         lift = 0.55
#
#
# 1
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.62
#         confidence = 0.10
#         lift = 0.73
#
#
# 2
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.62
#         confidence = 0.06
#         lift = 0.46
#
#
# 3
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.62
#         confidence = 0.16
#         lift = 0.66
#
#
# 4
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.62
#         confidence = 0.04
#         lift = 0.53
#
#
# 5
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.62
#         confidence = 0.04
#         lift = 0.37
#
#
# 6
# final loop check
# LENGTH OF RULESET 1
# Got 2 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({2}), support=0.38902743142144636, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({2}), confidence=0.38902743142144636, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.39
#         confidence = 0.28
#         lift = 0.88
#
#
# 7
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.39
#         confidence = 0.16
#         lift = 1.17
#
#
# 8
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.39
#         confidence = 0.10
#         lift = 0.73
#
#
# 9
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.39
#         confidence = 0.26
#         lift = 1.06
#
#
# 10
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.39
#         confidence = 0.06
#         lift = 0.86
#
#
# 11
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.39
#         confidence = 0.06
#         lift = 0.59
#
#
# 12
# final loop check
# LENGTH OF RULESET 1
# Got 3 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({3}), support=0.4613466334164589, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({3}), confidence=0.4613466334164589, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.46
#         confidence = 0.23
#         lift = 0.75
#
#
# 13
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.46
#         confidence = 0.14
#         lift = 0.98
#
#
# 14
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.46
#         confidence = 0.09
#         lift = 0.62
#
#
# 15
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.46
#         confidence = 0.22
#         lift = 0.90
#
#
# 16
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.72
#
#
# 17
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.50
#
#
# 18
# final loop check
# LENGTH OF RULESET 1
# Got 4 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({6}), support=0.3092269326683292, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({6}), confidence=0.3092269326683292, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.31
#         confidence = 0.35
#         lift = 1.11
#
#
# 19
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.20
#         lift = 1.47
#
#
# 20
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.31
#         confidence = 0.13
#         lift = 0.92
#
#
# 21
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.31
#         confidence = 0.33
#         lift = 1.34
#
#
# 22
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.31
#         confidence = 0.07
#         lift = 1.08
#
#
# 23
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.31
#         confidence = 0.07
#         lift = 0.75
#
#
# 24
# final loop check
# LENGTH OF RULESET 1
# Got 5 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({10}), support=0.256857855361596, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({10}), confidence=0.256857855361596, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.26
#         confidence = 0.42
#         lift = 1.34
#
#
# 25
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.77
#
#
# 26
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.26
#         confidence = 0.16
#         lift = 1.11
#
#
# 27
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.26
#         confidence = 0.40
#         lift = 1.61
#
#
# 28
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.30
#
#
# 29
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.90
#
#
# 30
# final loop check
# LENGTH OF RULESET 1
# Got 6 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({22}), support=0.26184538653366585, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({22}), confidence=0.26184538653366585, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.26
#         confidence = 0.41
#         lift = 1.31
#
#
# 31
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.74
#
#
# 32
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.26
#         confidence = 0.15
#         lift = 1.09
#
#
# 33
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.26
#         confidence = 0.39
#         lift = 1.58
#
#
# 34
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.27
#
#
# 35
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.88
#
#
# 36
# final loop check
# LENGTH OF RULESET 1
# Got 7 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({25}), support=0.38403990024937656, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({25}), confidence=0.38403990024937656, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.38
#         confidence = 0.28
#         lift = 0.90
#
#
# 37
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.38
#         confidence = 0.16
#         lift = 1.18
#
#
# 38
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.38
#         confidence = 0.10
#         lift = 0.74
#
#
# 39
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.38
#         confidence = 0.27
#         lift = 1.08
#
#
# 40
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.38
#         confidence = 0.06
#         lift = 0.87
#
#
# 41
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.38
#         confidence = 0.06
#         lift = 0.60
#
#
# 42
# final loop check
# LENGTH OF RULESET 1
# Got 8 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({27}), support=0.456359102244389, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({27}), confidence=0.456359102244389, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.46
#         confidence = 0.23
#         lift = 0.75
#
#
# 43
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.46
#         confidence = 0.14
#         lift = 1.00
#
#
# 44
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.46
#         confidence = 0.09
#         lift = 0.63
#
#
# 45
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.46
#         confidence = 0.22
#         lift = 0.91
#
#
# 46
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.73
#
#
# 47
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.51
#
#
# 48
# final loop check
# LENGTH OF RULESET 1
# Got 9 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({32}), support=0.4837905236907731, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({32}), confidence=0.4837905236907731, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.48
#         confidence = 0.22
#         lift = 0.71
#
#
# 49
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.48
#         confidence = 0.13
#         lift = 0.94
#
#
# 50
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.48
#         confidence = 0.08
#         lift = 0.59
#
#
# 51
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.48
#         confidence = 0.21
#         lift = 0.86
#
#
# 52
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.48
#         confidence = 0.05
#         lift = 0.69
#
#
# 53
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.48
#         confidence = 0.05
#         lift = 0.48
#
#
# 54
# final loop check
# LENGTH OF RULESET 1
# Got 10 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({46}), support=0.22194513715710723, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({46}), confidence=0.22194513715710723, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.22
#         confidence = 0.48
#         lift = 1.55
#
#
# 55
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.22
#         confidence = 0.28
#         lift = 2.05
#
#
# 56
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.22
#         confidence = 0.18
#         lift = 1.29
#
#
# 57
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.22
#         confidence = 0.46
#         lift = 1.87
#
#
# 58
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.22
#         confidence = 0.10
#         lift = 1.50
#
#
# 59
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.22
#         confidence = 0.10
#         lift = 1.04
#
#
# 60
# final loop check
# LENGTH OF RULESET 1
# Got 11 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({61}), support=0.3690773067331671, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({61}), confidence=0.3690773067331671, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.37
#         confidence = 0.29
#         lift = 0.93
#
#
# 61
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.37
#         confidence = 0.17
#         lift = 1.23
#
#
# 62
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.37
#         confidence = 0.11
#         lift = 0.77
#
#
# 63
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.37
#         confidence = 0.28
#         lift = 1.12
#
#
# 64
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.37
#         confidence = 0.06
#         lift = 0.90
#
#
# 65
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.37
#         confidence = 0.06
#         lift = 0.62
#
#
# 66
# final loop check
# LENGTH OF RULESET 1
# Got 12 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({62}), support=0.57356608478803, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({62}), confidence=0.57356608478803, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.57
#         confidence = 0.19
#         lift = 0.60
#
#
# 67
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.57
#         confidence = 0.11
#         lift = 0.79
#
#
# 68
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.57
#         confidence = 0.07
#         lift = 0.50
#
#
# 69
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.57
#         confidence = 0.18
#         lift = 0.72
#
#
# 70
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.57
#         confidence = 0.04
#         lift = 0.58
#
#
# 71
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.57
#         confidence = 0.04
#         lift = 0.40
#
#
# 72
# final loop check
# LENGTH OF RULESET 1
# Got 13 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({69}), support=0.3117206982543641, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({69}), confidence=0.3117206982543641, lift=1.0)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 1
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.31
#         confidence = 0.34
#         lift = 1.10
#
#
# 73
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.20
#         lift = 1.46
#
#
# 74
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.31
#         confidence = 0.13
#         lift = 0.92
#
#
# 75
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.31
#         confidence = 0.33
#         lift = 1.33
#
#
# 76
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.31
#         confidence = 0.07
#         lift = 1.07
#
#
# 77
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.31
#         confidence = 0.07
#         lift = 0.74
#
#
# 78
# final loop check
# LENGTH OF RULESET 3
# Got 14 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 2}), support=0.2344139650872818, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 2}), confidence=0.2344139650872818, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({2}), confidence=0.376, lift=0.9665128205128206), OrderedStatistic(items_base=frozenset({2}), items_add=frozenset({0}), confidence=0.6025641025641026, lift=0.9665128205128206)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['IsMajor'] -> IsCalm has
#         support = 0.23
#         confidence = 0.65
#         lift = 2.08
#
#
# 79
# Rule ['IsMajor'] -> IsCheerful has
#         support = 0.23
#         confidence = 0.29
#         lift = 2.09
#
#
# 80
# Rule ['IsMajor'] -> IsBravery has
#         support = 0.23
#         confidence = 0.22
#         lift = 1.60
#
#
# 81
# Rule ['IsMajor'] -> IsFearful has
#         support = 0.23
#         confidence = 0.24
#         lift = 0.99
#
#
# 82
# Rule ['IsMajor'] -> IsLove has
#         support = 0.23
#         confidence = 0.07
#         lift = 1.11
#
#
# 83
# Rule ['IsMajor'] -> IsSadness has
#         support = 0.23
#         confidence = 0.18
#         lift = 1.86
#
#
# 84
# final loop check
# LENGTH OF RULESET 3
# Got 15 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 3}), support=0.29925187032418954, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 3}), confidence=0.29925187032418954, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({3}), confidence=0.48, lift=1.0404324324324323), OrderedStatistic(items_base=frozenset({3}), items_add=frozenset({0}), confidence=0.6486486486486487, lift=1.0404324324324326)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['IsMinor'] -> IsCalm has
#         support = 0.30
#         confidence = 0.39
#         lift = 1.26
#
#
# 85
# Rule ['IsMinor'] -> IsCheerful has
#         support = 0.30
#         confidence = 0.20
#         lift = 1.46
#
#
# 86
# Rule ['IsMinor'] -> IsBravery has
#         support = 0.30
#         confidence = 0.21
#         lift = 1.49
#
#
# 87
# Rule ['IsMinor'] -> IsFearful has
#         support = 0.30
#         confidence = 0.45
#         lift = 1.82
#
#
# 88
# Rule ['IsMinor'] -> IsLove has
#         support = 0.30
#         confidence = 0.14
#         lift = 2.11
#
#
# 89
# Rule ['IsMinor'] -> IsSadness has
#         support = 0.30
#         confidence = 0.15
#         lift = 1.54
#
#
# 90
# final loop check
# LENGTH OF RULESET 3
# Got 16 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 27}), support=0.30673316708229426, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 27}), confidence=0.30673316708229426, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({27}), confidence=0.49199999999999994, lift=1.0780983606557375), OrderedStatistic(items_base=frozenset({27}), items_add=frozenset({0}), confidence=0.6721311475409836, lift=1.0780983606557375)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCalm has
#         support = 0.31
#         confidence = 0.43
#         lift = 1.38
#
#
# 91
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.21
#         lift = 1.54
#
#
# 92
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsBravery has
#         support = 0.31
#         confidence = 0.19
#         lift = 1.34
#
#
# 93
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsFearful has
#         support = 0.31
#         confidence = 0.35
#         lift = 1.42
#
#
# 94
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsLove has
#         support = 0.31
#         confidence = 0.18
#         lift = 2.66
#
#
# 95
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsSadness has
#         support = 0.31
#         confidence = 0.13
#         lift = 1.34
#
#
# 96
# final loop check
# LENGTH OF RULESET 3
# Got 17 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 32}), support=0.3266832917705736, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 32}), confidence=0.3266832917705736, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({32}), confidence=0.524, lift=1.0831134020618558), OrderedStatistic(items_base=frozenset({32}), items_add=frozenset({0}), confidence=0.6752577319587629, lift=1.0831134020618558)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.33
#         confidence = 0.40
#         lift = 1.30
#
#
# 97
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.33
#         confidence = 0.19
#         lift = 1.39
#
#
# 98
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.33
#         confidence = 0.23
#         lift = 1.64
#
#
# 99
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.33
#         confidence = 0.35
#         lift = 1.42
#
#
# 100
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.33
#         confidence = 0.15
#         lift = 2.27
#
#
# 101
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.33
#         confidence = 0.15
#         lift = 1.57
#
#
# 102
# final loop check
# LENGTH OF RULESET 3
# Got 18 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 61}), support=0.256857855361596, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 61}), confidence=0.256857855361596, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({61}), confidence=0.412, lift=1.1162972972972973), OrderedStatistic(items_base=frozenset({61}), items_add=frozenset({0}), confidence=0.6959459459459459, lift=1.1162972972972973)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsCalm has
#         support = 0.26
#         confidence = 0.43
#         lift = 1.37
#
#
# 103
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.77
#
#
# 104
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsBravery has
#         support = 0.26
#         confidence = 0.17
#         lift = 1.25
#
#
# 105
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsFearful has
#         support = 0.26
#         confidence = 0.42
#         lift = 1.69
#
#
# 106
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.30
#
#
# 107
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.90
#
#
# 108
# final loop check
# LENGTH OF RULESET 3
# Got 19 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 62}), support=0.38403990024937656, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 62}), confidence=0.38403990024937656, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({62}), confidence=0.616, lift=1.073982608695652), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({0}), confidence=0.6695652173913044, lift=1.073982608695652)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.38
#         confidence = 0.46
#         lift = 1.48
#
#
# 109
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.38
#         confidence = 0.25
#         lift = 1.85
#
#
# 110
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.38
#         confidence = 0.19
#         lift = 1.35
#
#
# 111
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.38
#         confidence = 0.37
#         lift = 1.50
#
#
# 112
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.38
#         confidence = 0.08
#         lift = 1.25
#
#
# 113
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.38
#         confidence = 0.14
#         lift = 1.40
#
#
# 114
# final loop check
# LENGTH OF RULESET 3
# Got 20 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({2, 62}), support=0.23940149625935161, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({2, 62}), confidence=0.23940149625935161, lift=1.0), OrderedStatistic(items_base=frozenset({2}), items_add=frozenset({62}), confidence=0.6153846153846154, lift=1.0729096989966556), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({2}), confidence=0.41739130434782606, lift=1.0729096989966556)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.24
#         confidence = 0.74
#         lift = 2.37
#
#
# 115
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.24
#         confidence = 0.41
#         lift = 2.96
#
#
# 116
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.24
#         confidence = 0.30
#         lift = 2.16
#
#
# 117
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.24
#         confidence = 0.59
#         lift = 2.40
#
#
# 118
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.24
#         confidence = 0.14
#         lift = 2.01
#
#
# 119
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.24
#         confidence = 0.22
#         lift = 2.25
#
#
# 120
# final loop check
# LENGTH OF RULESET 3
# Got 21 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({32, 3}), support=0.22194513715710723, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({32, 3}), confidence=0.22194513715710723, lift=1.0), OrderedStatistic(items_base=frozenset({3}), items_add=frozenset({32}), confidence=0.48108108108108105, lift=0.9943995541933686), OrderedStatistic(items_base=frozenset({32}), items_add=frozenset({3}), confidence=0.4587628865979381, lift=0.9943995541933686)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.22
#         confidence = 0.60
#         lift = 1.91
#
#
# 121
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.22
#         confidence = 0.28
#         lift = 2.05
#
#
# 122
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.22
#         confidence = 0.34
#         lift = 2.41
#
#
# 123
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.22
#         confidence = 0.52
#         lift = 2.09
#
#
# 124
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.22
#         confidence = 0.22
#         lift = 3.34
#
#
# 125
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.22
#         confidence = 0.22
#         lift = 2.31
#
#
# 126
# final loop check
# LENGTH OF RULESET 3
# Got 22 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({3, 62}), support=0.2518703241895262, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({3, 62}), confidence=0.2518703241895262, lift=1.0), OrderedStatistic(items_base=frozenset({3}), items_add=frozenset({62}), confidence=0.5459459459459459, lift=0.9518448883666274), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({3}), confidence=0.4391304347826087, lift=0.9518448883666275)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.25
#         confidence = 0.70
#         lift = 2.26
#
#
# 127
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.25
#         confidence = 0.39
#         lift = 2.81
#
#
# 128
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.25
#         confidence = 0.29
#         lift = 2.06
#
#
# 129
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.25
#         confidence = 0.56
#         lift = 2.29
#
#
# 130
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.25
#         confidence = 0.13
#         lift = 1.91
#
#
# 131
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.25
#         confidence = 0.21
#         lift = 2.14
#
#
# 132
# final loop check
# LENGTH OF RULESET 3
# Got 23 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({25, 6}), support=0.2543640897755611, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({25, 6}), confidence=0.2543640897755611, lift=1.0), OrderedStatistic(items_base=frozenset({6}), items_add=frozenset({25}), confidence=0.8225806451612903, lift=2.1419145370758272), OrderedStatistic(items_base=frozenset({25}), items_add=frozenset({6}), confidence=0.6623376623376622, lift=2.141914537075827)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsCalm has
#         support = 0.25
#         confidence = 0.38
#         lift = 1.23
#
#
# 133
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsCheerful has
#         support = 0.25
#         confidence = 0.20
#         lift = 1.43
#
#
# 134
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsBravery has
#         support = 0.25
#         confidence = 0.28
#         lift = 2.04
#
#
# 135
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsFearful has
#         support = 0.25
#         confidence = 0.40
#         lift = 1.63
#
#
# 136
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsLove has
#         support = 0.25
#         confidence = 0.08
#         lift = 1.17
#
#
# 137
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsSadness has
#         support = 0.25
#         confidence = 0.17
#         lift = 1.71
#
#
# 138
# final loop check
# LENGTH OF RULESET 3
# Got 24 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({27, 22}), support=0.26184538653366585, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({27, 22}), confidence=0.26184538653366585, lift=1.0), OrderedStatistic(items_base=frozenset({22}), items_add=frozenset({27}), confidence=1.0, lift=2.191256830601093), OrderedStatistic(items_base=frozenset({27}), items_add=frozenset({22}), confidence=0.5737704918032788, lift=2.1912568306010933)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCalm has
#         support = 0.26
#         confidence = 0.50
#         lift = 1.62
#
#
# 139
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.25
#         lift = 1.80
#
#
# 140
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsBravery has
#         support = 0.26
#         confidence = 0.22
#         lift = 1.57
#
#
# 141
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsFearful has
#         support = 0.26
#         confidence = 0.41
#         lift = 1.66
#
#
# 142
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsLove has
#         support = 0.26
#         confidence = 0.21
#         lift = 3.11
#
#
# 143
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsSadness has
#         support = 0.26
#         confidence = 0.15
#         lift = 1.57
#
#
# 144
# final loop check
# LENGTH OF RULESET 3
# Got 25 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({32, 27}), support=0.2942643391521197, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({32, 27}), confidence=0.2942643391521197, lift=1.0), OrderedStatistic(items_base=frozenset({27}), items_add=frozenset({32}), confidence=0.6448087431693988, lift=1.3328263196439636), OrderedStatistic(items_base=frozenset({32}), items_add=frozenset({27}), confidence=0.6082474226804123, lift=1.3328263196439636)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.29
#         confidence = 0.45
#         lift = 1.44
#
#
# 145
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.29
#         confidence = 0.21
#         lift = 1.54
#
#
# 146
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.29
#         confidence = 0.25
#         lift = 1.82
#
#
# 147
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.29
#         confidence = 0.39
#         lift = 1.58
#
#
# 148
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.29
#         confidence = 0.17
#         lift = 2.52
#
#
# 149
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.29
#         confidence = 0.17
#         lift = 1.74
#
#
# 150
# final loop check
# LENGTH OF RULESET 3
# Got 26 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({27, 62}), support=0.2817955112219451, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({27, 62}), confidence=0.2817955112219451, lift=1.0), OrderedStatistic(items_base=frozenset({27}), items_add=frozenset({62}), confidence=0.6174863387978142, lift=1.0765740080779282), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({27}), confidence=0.4913043478260869, lift=1.076574008077928)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.28
#         confidence = 0.63
#         lift = 2.02
#
#
# 151
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.28
#         confidence = 0.35
#         lift = 2.52
#
#
# 152
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.28
#         confidence = 0.26
#         lift = 1.84
#
#
# 153
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.28
#         confidence = 0.50
#         lift = 2.04
#
#
# 154
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.28
#         confidence = 0.12
#         lift = 1.71
#
#
# 155
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.28
#         confidence = 0.19
#         lift = 1.91
#
#
# 156
# final loop check
# LENGTH OF RULESET 3
# Got 27 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({32, 62}), support=0.2817955112219451, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({32, 62}), confidence=0.2817955112219451, lift=1.0), OrderedStatistic(items_base=frozenset({32}), items_add=frozenset({62}), confidence=0.5824742268041236, lift=1.015531151949798), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({32}), confidence=0.4913043478260869, lift=1.015531151949798)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.28
#         confidence = 0.63
#         lift = 2.02
#
#
# 157
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.28
#         confidence = 0.35
#         lift = 2.52
#
#
# 158
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.28
#         confidence = 0.26
#         lift = 1.84
#
#
# 159
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.28
#         confidence = 0.50
#         lift = 2.04
#
#
# 160
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.28
#         confidence = 0.12
#         lift = 1.71
#
#
# 161
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.28
#         confidence = 0.19
#         lift = 1.91
#
#
# 162
# final loop check
# LENGTH OF RULESET 3
# Got 28 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({61, 62}), support=0.3566084788029925, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({61, 62}), confidence=0.3566084788029925, lift=1.0), OrderedStatistic(items_base=frozenset({61}), items_add=frozenset({62}), confidence=0.9662162162162162, lift=1.6845769682726204), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({61}), confidence=0.6217391304347826, lift=1.6845769682726204)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 2
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.36
#         confidence = 0.50
#         lift = 1.59
#
#
# 163
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.36
#         confidence = 0.27
#         lift = 1.99
#
#
# 164
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.36
#         confidence = 0.20
#         lift = 1.45
#
#
# 165
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.36
#         confidence = 0.40
#         lift = 1.61
#
#
# 166
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.36
#         confidence = 0.09
#         lift = 1.35
#
#
# 167
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.36
#         confidence = 0.15
#         lift = 1.51
#
#
# 168
# final loop check
# LENGTH OF RULESET 7
# Got 29 itemsets
# THIS IS THE RULESET RelationRecord(items=frozenset({0, 61, 62}), support=0.24438902743142144, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({0, 61, 62}), confidence=0.24438902743142144, lift=1.0), OrderedStatistic(items_base=frozenset({0}), items_add=frozenset({61, 62}), confidence=0.39199999999999996, lift=1.099244755244755), OrderedStatistic(items_base=frozenset({61}), items_add=frozenset({0, 62}), confidence=0.6621621621621622, lift=1.7242014742014742), OrderedStatistic(items_base=frozenset({62}), items_add=frozenset({0, 61}), confidence=0.4260869565217391, lift=1.6588433938370621), OrderedStatistic(items_base=frozenset({0, 61}), items_add=frozenset({62}), confidence=0.9514563106796117, lift=1.658843393837062), OrderedStatistic(items_base=frozenset({0, 62}), items_add=frozenset({61}), confidence=0.6363636363636364, lift=1.7242014742014742), OrderedStatistic(items_base=frozenset({61, 62}), items_add=frozenset({0}), confidence=0.6853146853146853, lift=1.0992447552447553)])
# 1st loop check
# ITEMS BASE 0
# ITEMS add 3
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 2
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 2
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 1
# ITEMS add 2
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 2
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 2
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# 1st loop check
# ITEMS BASE 2
# ITEMS add 1
# check
# ruleset.ordered_statistics loop ends check
# list features loop check
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.24
#         confidence = 0.44
#         lift = 1.41
#
#
# 169
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.24
#         confidence = 0.26
#         lift = 1.86
#
#
# 170
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.24
#         confidence = 0.16
#         lift = 1.17
#
#
# 171
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.24
#         confidence = 0.42
#         lift = 1.69
#
#
# 172
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.24
#         confidence = 0.09
#         lift = 1.36
#
#
# 173
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.24
#         confidence = 0.09
#         lift = 0.94
#
#
# 174
# final loop check

# %%
"""
This class is an adapter for the KMeans approach.
"""
class KMeansAdapter(AbstractCustomModel):
 
    """
    This is the default constructor for this class.
 
    Parameters:
    params : dict - hyperparameters for the model
    """
    def __init__(self,params):
        self.params = params
        super().__init__()
 
    """
    This method trains the model on the given dataset
 
    Parameters:
    x_train : numpy.ndarray - training set data
    """
    def train(self,x_train,y_train=None):
        # TODO
        pass
 
    """
    This method evaluates the performance of the model on the given test set.
 
    Parameters:
    x_test : numpy.ndarray - test set data
 
    Returns:
    A floating point number which measures the performance of the model on the 
    test set.
    """
    def evaluate(self,x_test,y_test=None):
        # TODO
        pass

# %%
for ruleset in model.results:   
    for ord in ruleset.ordered_statistics:
        if len(ord.items_base) > 0 and len(ord.items_add) > 0:
            featurelist = []
            for i in ord.items_base:
                featurelist.append(features[i])         
        list_features = list(featurelist) 
    
    colno = []
    
    for i in list_features:
        colno.append(features.index(i))
    
    emotioncol = 69
    
    for k in emotion_val:
        confcount = 0
        for i in range(row_count):
            s = True
            for j in colno:
                if(x_train[i][j] == 1 and x_train[i][emotioncol] == k and s == True):
                    s = True
                else:
                    s = False  
                    
            if(s == True):
                confcount += 1
    
        confidence = (confcount/row_count) / ruleset.support
        lift = confidence / lift_supp[emotion_val.index(k)]

        print("""Rule {} -> {} has
        support = {:.2f}
        confidence = {:.2f}
        lift = {:.2f}

        """.format(list(featurelist),emotions[k-1],ruleset.support,\
                    confidence,lift))

        rules += 1
# Out:
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.62
#         confidence = 0.17
#         lift = 0.55
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.62
#         confidence = 0.10
#         lift = 0.73
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.62
#         confidence = 0.06
#         lift = 0.46
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.62
#         confidence = 0.16
#         lift = 0.66
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.62
#         confidence = 0.04
#         lift = 0.53
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.62
#         confidence = 0.04
#         lift = 0.37
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.39
#         confidence = 0.28
#         lift = 0.88
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.39
#         confidence = 0.16
#         lift = 1.17
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.39
#         confidence = 0.10
#         lift = 0.73
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.39
#         confidence = 0.26
#         lift = 1.06
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.39
#         confidence = 0.06
#         lift = 0.86
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.39
#         confidence = 0.06
#         lift = 0.59
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.46
#         confidence = 0.23
#         lift = 0.75
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.46
#         confidence = 0.14
#         lift = 0.98
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.46
#         confidence = 0.09
#         lift = 0.62
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.46
#         confidence = 0.22
#         lift = 0.90
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.72
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.50
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.31
#         confidence = 0.35
#         lift = 1.11
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.20
#         lift = 1.47
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.31
#         confidence = 0.13
#         lift = 0.92
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.31
#         confidence = 0.33
#         lift = 1.34
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.31
#         confidence = 0.07
#         lift = 1.08
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.31
#         confidence = 0.07
#         lift = 0.75
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.26
#         confidence = 0.42
#         lift = 1.34
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.77
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.26
#         confidence = 0.16
#         lift = 1.11
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.26
#         confidence = 0.40
#         lift = 1.61
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.30
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.90
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.26
#         confidence = 0.41
#         lift = 1.31
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.74
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.26
#         confidence = 0.15
#         lift = 1.09
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.26
#         confidence = 0.39
#         lift = 1.58
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.27
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.88
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.38
#         confidence = 0.28
#         lift = 0.90
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.38
#         confidence = 0.16
#         lift = 1.18
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.38
#         confidence = 0.10
#         lift = 0.74
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.38
#         confidence = 0.27
#         lift = 1.08
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.38
#         confidence = 0.06
#         lift = 0.87
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.38
#         confidence = 0.06
#         lift = 0.60
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.46
#         confidence = 0.23
#         lift = 0.75
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.46
#         confidence = 0.14
#         lift = 1.00
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.46
#         confidence = 0.09
#         lift = 0.63
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.46
#         confidence = 0.22
#         lift = 0.91
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.73
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.46
#         confidence = 0.05
#         lift = 0.51
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.48
#         confidence = 0.22
#         lift = 0.71
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.48
#         confidence = 0.13
#         lift = 0.94
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.48
#         confidence = 0.08
#         lift = 0.59
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.48
#         confidence = 0.21
#         lift = 0.86
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.48
#         confidence = 0.05
#         lift = 0.69
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.48
#         confidence = 0.05
#         lift = 0.48
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.22
#         confidence = 0.48
#         lift = 1.55
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.22
#         confidence = 0.28
#         lift = 2.05
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.22
#         confidence = 0.18
#         lift = 1.29
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.22
#         confidence = 0.46
#         lift = 1.87
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.22
#         confidence = 0.10
#         lift = 1.50
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.22
#         confidence = 0.10
#         lift = 1.04
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.37
#         confidence = 0.29
#         lift = 0.93
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.37
#         confidence = 0.17
#         lift = 1.23
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.37
#         confidence = 0.11
#         lift = 0.77
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.37
#         confidence = 0.28
#         lift = 1.12
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.37
#         confidence = 0.06
#         lift = 0.90
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.37
#         confidence = 0.06
#         lift = 0.62
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.57
#         confidence = 0.19
#         lift = 0.60
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.57
#         confidence = 0.11
#         lift = 0.79
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.57
#         confidence = 0.07
#         lift = 0.50
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.57
#         confidence = 0.18
#         lift = 0.72
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.57
#         confidence = 0.04
#         lift = 0.58
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.57
#         confidence = 0.04
#         lift = 0.40
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.31
#         confidence = 0.34
#         lift = 1.10
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.20
#         lift = 1.46
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.31
#         confidence = 0.13
#         lift = 0.92
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.31
#         confidence = 0.33
#         lift = 1.33
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.31
#         confidence = 0.07
#         lift = 1.07
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.31
#         confidence = 0.07
#         lift = 0.74
#
#
# Rule ['IsMajor'] -> IsCalm has
#         support = 0.23
#         confidence = 0.65
#         lift = 2.08
#
#
# Rule ['IsMajor'] -> IsCheerful has
#         support = 0.23
#         confidence = 0.29
#         lift = 2.09
#
#
# Rule ['IsMajor'] -> IsBravery has
#         support = 0.23
#         confidence = 0.22
#         lift = 1.60
#
#
# Rule ['IsMajor'] -> IsFearful has
#         support = 0.23
#         confidence = 0.24
#         lift = 0.99
#
#
# Rule ['IsMajor'] -> IsLove has
#         support = 0.23
#         confidence = 0.07
#         lift = 1.11
#
#
# Rule ['IsMajor'] -> IsSadness has
#         support = 0.23
#         confidence = 0.18
#         lift = 1.86
#
#
# Rule ['IsMinor'] -> IsCalm has
#         support = 0.30
#         confidence = 0.39
#         lift = 1.26
#
#
# Rule ['IsMinor'] -> IsCheerful has
#         support = 0.30
#         confidence = 0.20
#         lift = 1.46
#
#
# Rule ['IsMinor'] -> IsBravery has
#         support = 0.30
#         confidence = 0.21
#         lift = 1.49
#
#
# Rule ['IsMinor'] -> IsFearful has
#         support = 0.30
#         confidence = 0.45
#         lift = 1.82
#
#
# Rule ['IsMinor'] -> IsLove has
#         support = 0.30
#         confidence = 0.14
#         lift = 2.11
#
#
# Rule ['IsMinor'] -> IsSadness has
#         support = 0.30
#         confidence = 0.15
#         lift = 1.54
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCalm has
#         support = 0.31
#         confidence = 0.43
#         lift = 1.38
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCheerful has
#         support = 0.31
#         confidence = 0.21
#         lift = 1.54
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsBravery has
#         support = 0.31
#         confidence = 0.19
#         lift = 1.34
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsFearful has
#         support = 0.31
#         confidence = 0.35
#         lift = 1.42
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsLove has
#         support = 0.31
#         confidence = 0.18
#         lift = 2.66
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsSadness has
#         support = 0.31
#         confidence = 0.13
#         lift = 1.34
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.33
#         confidence = 0.40
#         lift = 1.30
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.33
#         confidence = 0.19
#         lift = 1.39
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.33
#         confidence = 0.23
#         lift = 1.64
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.33
#         confidence = 0.35
#         lift = 1.42
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.33
#         confidence = 0.15
#         lift = 2.27
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.33
#         confidence = 0.15
#         lift = 1.57
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsCalm has
#         support = 0.26
#         confidence = 0.43
#         lift = 1.37
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.24
#         lift = 1.77
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsBravery has
#         support = 0.26
#         confidence = 0.17
#         lift = 1.25
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsFearful has
#         support = 0.26
#         confidence = 0.42
#         lift = 1.69
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsLove has
#         support = 0.26
#         confidence = 0.09
#         lift = 1.30
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation'] -> IsSadness has
#         support = 0.26
#         confidence = 0.09
#         lift = 0.90
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.38
#         confidence = 0.46
#         lift = 1.48
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.38
#         confidence = 0.25
#         lift = 1.85
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.38
#         confidence = 0.19
#         lift = 1.35
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.38
#         confidence = 0.37
#         lift = 1.50
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.38
#         confidence = 0.08
#         lift = 1.25
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.38
#         confidence = 0.14
#         lift = 1.40
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.24
#         confidence = 0.74
#         lift = 2.37
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.24
#         confidence = 0.41
#         lift = 2.96
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.24
#         confidence = 0.30
#         lift = 2.16
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.24
#         confidence = 0.59
#         lift = 2.40
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.24
#         confidence = 0.14
#         lift = 2.01
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.24
#         confidence = 0.22
#         lift = 2.25
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.22
#         confidence = 0.60
#         lift = 1.91
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.22
#         confidence = 0.28
#         lift = 2.05
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.22
#         confidence = 0.34
#         lift = 2.41
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.22
#         confidence = 0.52
#         lift = 2.09
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.22
#         confidence = 0.22
#         lift = 3.34
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.22
#         confidence = 0.22
#         lift = 2.31
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.25
#         confidence = 0.70
#         lift = 2.26
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.25
#         confidence = 0.39
#         lift = 2.81
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.25
#         confidence = 0.29
#         lift = 2.06
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.25
#         confidence = 0.56
#         lift = 2.29
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.25
#         confidence = 0.13
#         lift = 1.91
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.25
#         confidence = 0.21
#         lift = 2.14
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsCalm has
#         support = 0.25
#         confidence = 0.38
#         lift = 1.23
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsCheerful has
#         support = 0.25
#         confidence = 0.20
#         lift = 1.43
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsBravery has
#         support = 0.25
#         confidence = 0.28
#         lift = 2.04
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsFearful has
#         support = 0.25
#         confidence = 0.40
#         lift = 1.63
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsLove has
#         support = 0.25
#         confidence = 0.08
#         lift = 1.17
#
#
# Rule ['Running Mean of Spectral Rolloff Point Overall Average'] -> IsSadness has
#         support = 0.25
#         confidence = 0.17
#         lift = 1.71
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCalm has
#         support = 0.26
#         confidence = 0.50
#         lift = 1.62
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsCheerful has
#         support = 0.26
#         confidence = 0.25
#         lift = 1.80
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsBravery has
#         support = 0.26
#         confidence = 0.22
#         lift = 1.57
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsFearful has
#         support = 0.26
#         confidence = 0.41
#         lift = 1.66
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsLove has
#         support = 0.26
#         confidence = 0.21
#         lift = 3.11
#
#
# Rule ['Running Mean of Spectral Variability Overall Standard Deviation'] -> IsSadness has
#         support = 0.26
#         confidence = 0.15
#         lift = 1.57
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCalm has
#         support = 0.29
#         confidence = 0.45
#         lift = 1.44
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsCheerful has
#         support = 0.29
#         confidence = 0.21
#         lift = 1.54
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsBravery has
#         support = 0.29
#         confidence = 0.25
#         lift = 1.82
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsFearful has
#         support = 0.29
#         confidence = 0.39
#         lift = 1.58
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsLove has
#         support = 0.29
#         confidence = 0.17
#         lift = 2.52
#
#
# Rule ['Standard Deviation of Compactness Overall Standard Deviation'] -> IsSadness has
#         support = 0.29
#         confidence = 0.17
#         lift = 1.74
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.28
#         confidence = 0.63
#         lift = 2.02
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.28
#         confidence = 0.35
#         lift = 2.52
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.28
#         confidence = 0.26
#         lift = 1.84
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.28
#         confidence = 0.50
#         lift = 2.04
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.28
#         confidence = 0.12
#         lift = 1.71
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.28
#         confidence = 0.19
#         lift = 1.91
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.28
#         confidence = 0.63
#         lift = 2.02
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.28
#         confidence = 0.35
#         lift = 2.52
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.28
#         confidence = 0.26
#         lift = 1.84
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.28
#         confidence = 0.50
#         lift = 2.04
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.28
#         confidence = 0.12
#         lift = 1.71
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.28
#         confidence = 0.19
#         lift = 1.91
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.36
#         confidence = 0.50
#         lift = 1.59
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.36
#         confidence = 0.27
#         lift = 1.99
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.36
#         confidence = 0.20
#         lift = 1.45
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.36
#         confidence = 0.40
#         lift = 1.61
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.36
#         confidence = 0.09
#         lift = 1.35
#
#
# Rule ['Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.36
#         confidence = 0.15
#         lift = 1.51
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCalm has
#         support = 0.24
#         confidence = 0.44
#         lift = 1.41
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsCheerful has
#         support = 0.24
#         confidence = 0.26
#         lift = 1.86
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsBravery has
#         support = 0.24
#         confidence = 0.16
#         lift = 1.17
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsFearful has
#         support = 0.24
#         confidence = 0.42
#         lift = 1.69
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsLove has
#         support = 0.24
#         confidence = 0.09
#         lift = 1.36
#
#
# Rule ['Derivative of Running Mean of LPC Overall Standard Deviation', 'Derivative of Running Mean of Method of Moments Overall Average'] -> IsSadness has
#         support = 0.24
#         confidence = 0.09
#         lift = 0.94
