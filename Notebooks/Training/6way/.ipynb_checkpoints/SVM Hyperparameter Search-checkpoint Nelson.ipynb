# %%
# dependencies
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn import svm
# from sklearn.naive_bayes import ComplementNB, MultinomialNB
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from scipy.stats import uniform, norm
from sklearn.metrics import plot_confusion_matrix
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import SelectFromModel, SelectKBest, VarianceThreshold, chi2, f_classif, mutual_info_classif

from XLB import *

import warnings
warnings.filterwarnings('ignore')

# %%
# extract data from files
x_train, y_train = extract_data("Nelson_Set.csv")
x_val, y_val = extract_data("Nelson_Validation_Set.csv")

# scale data values
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)

# feature selection
num_features = 45
feat_sel = VarianceThreshold()
x_train = feat_sel.fit_transform(x_train)
# WINNER : 47.62% 0.43
feat_sel_2 = SelectFromModel(estimator=DecisionTreeClassifier(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=RandomForestClassifier(n_estimators=100,\
#                                              random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=LogisticRegression(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=svm.LinearSVC(C=0.01, penalty="l1", dual=False,\
#                                     random_state=481516234))
# feat_sel_2 = SelectKBest(mutual_info_classif,k=num_features)
x_train = feat_sel_2.fit_transform(x_train,y_train)
x_val = feat_sel_2.transform(feat_sel.transform(x_val))
# print("After Variance Threshold Feature Selection:",x_train.shape)

rand_seed = 3454132

oversampler = SMOTE(sampling_strategy="not majority",random_state=rand_seed, k_neighbors = 2)
x_smote, y_smote = oversampler.fit_resample(x_train,y_train)
print(x_smote.shape,y_smote.shape)

oversampler = RandomOverSampler(sampling_strategy="not majority",\
                                random_state=rand_seed)
x_os, y_os = oversampler.fit_resample(x_train,y_train)
print(x_os.shape,y_os.shape)
# Out:
# (402, 58) (402,)
# (402, 58) (402,)

# %%
themes = ["Calm","Cheerful","Bravery","Fearful","Love","Sadness"]

# %%
# NuSVC, Randomized Search
k_folds = 10
random_search_iterations = 200
rand_seed = 3249807

parameters = {
    'nu' : uniform(loc=0.0,scale=0.1),
    'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'shrinking' : [True,False],
    'probability' : [True,False],
    'max_iter' : [600],
    'break_ties' : [True,False]
}

nusvc = svm.NuSVC(random_state=rand_seed)
random_search_nu = RandomizedSearchCV(nusvc, parameters,\
                                          random_state=rand_seed,\
                                          n_iter=random_search_iterations,\
                                          cv=k_folds,n_jobs=-1)

# %%
    print_res_6_way("Vanilla",x_train,y_train,random_search_nu, themes, verbose = False)
    test_res_6_way("Vanilla",x_val,y_val,random_search_nu, themes)
# Out:
# Best Score: 0.2622
# Vanilla Train Accuracy: 41.1003%
# [1. 5. 1. 2. 6. 2. 6. 3. 1. 3. 5. 5. 5. 5.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Vanilla Validation Accuracy: 42.86%
# Vanilla F1-score: 0.38
# Vanilla Precision Score: 0.34
# Vanilla Recall Score: 0.43
# Vanilla ROC-AUC Score: 0.79
# Vanilla ROC-AUC Score: 0.71
# Vanilla ROC-AUC Score: 0.42
# Vanilla ROC-AUC Score: 0.50
# Vanilla ROC-AUC Score: 0.91
# Vanilla ROC-AUC Score: 0.42
# (42.857142857142854, 0.375)

# %%
    print_res_6_way("Random Oversampling",x_os,y_os,random_search_nu,themes, verbose = False)
    test_res_6_way("Random Oversampling",x_val,y_val,random_search_nu,themes)
# Out:
# Best Score: 0.5327
# Random Oversampling Train Accuracy: 99.5025%
# [5. 5. 4. 2. 1. 4. 6. 3. 1. 6. 5. 5. 5. 2.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Random Oversampling Validation Accuracy: 28.57%
# Random Oversampling F1-score: 0.23
# Random Oversampling Precision Score: 0.20
# Random Oversampling Recall Score: 0.29
# Random Oversampling ROC-AUC Score: 0.41
# Random Oversampling ROC-AUC Score: 0.71
# Random Oversampling ROC-AUC Score: 0.46
# Random Oversampling ROC-AUC Score: 0.41
# Random Oversampling ROC-AUC Score: 0.91
# Random Oversampling ROC-AUC Score: 0.42
# (28.57142857142857, 0.23214285714285712)

# %%
    print_res_6_way("SMOTE",x_smote,y_smote,random_search_nu,themes)
    test_res_6_way("SMOTE",x_val,y_val,random_search_nu,themes)
# Out:
# Best Score: 0.5454
# break_ties => False
# kernel => poly
# max_iter => 600
# nu => 0.07133071210873088
# probability => True
# shrinking => False
# Splits: 10
# SMOTE Train Accuracy: 100.0000%
# [1. 6. 4. 2. 1. 4. 6. 3. 1. 6. 5. 5. 5. 5.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# SMOTE Validation Accuracy: 35.71%
# SMOTE F1-score: 0.35
# SMOTE Precision Score: 0.38
# SMOTE Recall Score: 0.36
# SMOTE ROC-AUC Score: 0.58
# SMOTE ROC-AUC Score: 0.75
# SMOTE ROC-AUC Score: 0.46
# SMOTE ROC-AUC Score: 0.41
# SMOTE ROC-AUC Score: 0.95
# SMOTE ROC-AUC Score: 0.38
# (35.714285714285715, 0.3503401360544217)

# %%
# extract data from files
x_train, y_train = extract_data("Nelson_Set.csv")
x_val, y_val = extract_data("Nelson_Validation_Set.csv")

# scale data values
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)

# feature selection
num_features = 45
feat_sel = VarianceThreshold()
x_train = feat_sel.fit_transform(x_train)
# WINNER : 42.86% 0.34
feat_sel_2 = SelectFromModel(estimator=DecisionTreeClassifier(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=RandomForestClassifier(n_estimators=100,\
#                                              random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=LogisticRegression(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=svm.LinearSVC(C=0.01, penalty="l1", dual=False,\
#                                     random_state=481516234))
# feat_sel_2 = SelectKBest(mutual_info_classif,k=num_features)
x_train = feat_sel_2.fit_transform(x_train,y_train)
x_val = feat_sel_2.transform(feat_sel.transform(x_val))
# print("After Variance Threshold Feature Selection:",x_train.shape)

rand_seed = 3454132

oversampler = SMOTE(sampling_strategy="not majority",random_state=rand_seed, k_neighbors = 2)
x_smote, y_smote = oversampler.fit_resample(x_train,y_train)
print(x_smote.shape,y_smote.shape)

oversampler = RandomOverSampler(sampling_strategy="not majority",\
                                random_state=rand_seed)
x_os, y_os = oversampler.fit_resample(x_train,y_train)
print(x_os.shape,y_os.shape)
# Out:
# (402, 58) (402,)
# (402, 58) (402,)

# %%
# SVM, Grid Search
k_folds = 10
random_search_iterations = 200
rand_seed = 3249807

parameters = {
    'C': np.logspace(-10,0,100), 
    'gamma': ['scale', 'auto'], 
    'kernel':['linear', 'rbf', 'sigmoid', 'poly'], 
    'shrinking':[True, False], 
    'probability':[True, False],
    'max_iter' : [600],
    'break_ties' : [True, False]
}

svmc = svm.SVC(random_state=rand_seed)
random_search_svm = RandomizedSearchCV(svmc, parameters,\
                                       random_state=rand_seed,\
                                       n_iter=random_search_iterations,\
                                       cv=k_folds,n_jobs=-1)

# %%
    print_res_6_way("Vanilla",x_train,y_train,random_search_svm, themes, verbose = False)
    test_res_6_way("Vanilla",x_val,y_val,random_search_svm, themes)
# Out:
# Best Score: 0.2977
# Vanilla Train Accuracy: 36.5696%
# [1. 1. 5. 4. 3. 5. 5. 5. 4. 5. 5. 5. 5. 5.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Vanilla Validation Accuracy: 42.86%
# Vanilla F1-score: 0.36
# Vanilla Precision Score: 0.39
# Vanilla Recall Score: 0.43
# Vanilla ROC-AUC Score: 0.83
# Vanilla ROC-AUC Score: 0.50
# Vanilla ROC-AUC Score: 0.46
# Vanilla ROC-AUC Score: 0.62
# Vanilla ROC-AUC Score: 0.73
# Vanilla ROC-AUC Score: 0.50
# (42.857142857142854, 0.3642857142857143)

# %%
    print_res_6_way("Random Oversampling",x_os,y_os,random_search_svm,themes, verbose = False)
    test_res_6_way("Random Oversampling",x_val,y_val,random_search_svm,themes)
# Out:
# Best Score: 0.4334
# Random Oversampling Train Accuracy: 75.6219%
# [5. 6. 4. 4. 2. 6. 6. 3. 2. 6. 5. 5. 5. 2.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Random Oversampling Validation Accuracy: 28.57%
# Random Oversampling F1-score: 0.24
# Random Oversampling Precision Score: 0.21
# Random Oversampling Recall Score: 0.29
# Random Oversampling ROC-AUC Score: 0.50
# Random Oversampling ROC-AUC Score: 0.67
# Random Oversampling ROC-AUC Score: 0.46
# Random Oversampling ROC-AUC Score: 0.41
# Random Oversampling ROC-AUC Score: 0.95
# Random Oversampling ROC-AUC Score: 0.35
# (28.57142857142857, 0.24081632653061222)

# %%
    print_res_6_way("SMOTE",x_smote,y_smote,random_search_svm,themes)
    test_res_6_way("SMOTE",x_val,y_val,random_search_svm,themes)
# Out:
# Best Score: 0.4335
# shrinking => True
# probability => False
# max_iter => 600
# kernel => poly
# gamma => scale
# break_ties => True
# C => 1.0
# Splits: 10
# SMOTE Train Accuracy: 77.3632%
# [5. 6. 4. 2. 1. 4. 6. 3. 1. 6. 5. 6. 5. 3.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# SMOTE Validation Accuracy: 21.43%
# SMOTE F1-score: 0.24
# SMOTE Precision Score: 0.29
# SMOTE Recall Score: 0.21
# SMOTE ROC-AUC Score: 0.41
# SMOTE ROC-AUC Score: 0.75
# SMOTE ROC-AUC Score: 0.42
# SMOTE ROC-AUC Score: 0.41
# SMOTE ROC-AUC Score: 0.79
# SMOTE ROC-AUC Score: 0.35
# (21.428571428571427, 0.23809523809523808)

# %%
## extract data from files
x_train, y_train = extract_data("Nelson_Set.csv")
x_val, y_val = extract_data("Nelson_Validation_Set.csv")

# scale data values
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)

# feature selection
num_features = 45
feat_sel = VarianceThreshold()
x_train = feat_sel.fit_transform(x_train)
# feat_sel_2 = SelectFromModel(estimator=DecisionTreeClassifier(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=RandomForestClassifier(n_estimators=100,\
#                                              random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=LogisticRegression(random_state=481516234))
# feat_sel_2 = SelectFromModel(\
#                 estimator=svm.LinearSVC(C=0.01, penalty="l1", dual=False,\
#                                     random_state=481516234))
# 28.57% 0.28
feat_sel_2 = SelectKBest(chi2,k=num_features)
x_train = feat_sel_2.fit_transform(x_train,y_train)
x_val = feat_sel_2.transform(feat_sel.transform(x_val))
# print("After Variance Threshold Feature Selection:",x_train.shape)

rand_seed = 3454132

oversampler = SMOTE(sampling_strategy="not majority",random_state=rand_seed, k_neighbors = 2)
x_smote, y_smote = oversampler.fit_resample(x_train,y_train)
print(x_smote.shape,y_smote.shape)

oversampler = RandomOverSampler(sampling_strategy="not majority",\
                                random_state=rand_seed)
x_os, y_os = oversampler.fit_resample(x_train,y_train)
print(x_os.shape,y_os.shape)
# Out:
# (402, 45) (402,)
# (402, 45) (402,)

# %%
# LinearSVM, Randomized Search
k_folds = 10
random_search_iterations = 200
rand_seed = 3249807

parameters = {
    'penalty':['l1', 'l2'],
    'loss':['hinge', 'squared_hinge'], 
    'dual':[True, False], 
    'C': np.logspace(-10,0,100), 
    'multi_class':['ovr', 'crammer_singer'], 
    'fit_intercept' : [True,False],
    'max_iter':[600]
}

linearsvm = svm.LinearSVC(random_state=rand_seed)
random_search_linear = RandomizedSearchCV(linearsvm, parameters,\
                                          random_state=rand_seed,\
                                          n_iter=random_search_iterations,\
                                          cv=k_folds,n_jobs=-1)

# %%
    print_res_6_way("Vanilla",x_train,y_train,random_search_linear, themes, verbose = False)
    test_res_6_way("Vanilla",x_val,y_val,random_search_linear, themes)
# Out:
# Best Score: 0.2946
# Vanilla Train Accuracy: 30.7443%
# [5. 5. 5. 5. 2. 5. 5. 5. 5. 5. 5. 5. 5. 5.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Vanilla Validation Accuracy: 28.57%
# Vanilla F1-score: 0.18
# Vanilla Precision Score: 0.19
# Vanilla Recall Score: 0.29
# Vanilla ROC-AUC Score: 0.50
# Vanilla ROC-AUC Score: 0.75
# Vanilla ROC-AUC Score: 0.50
# Vanilla ROC-AUC Score: 0.50
# Vanilla ROC-AUC Score: 0.55
# Vanilla ROC-AUC Score: 0.50
# (28.57142857142857, 0.17559523809523808)

# %%
    print_res_6_way("Random Oversampling",x_os,y_os,random_search_linear,themes, verbose = False)
    test_res_6_way("Random Oversampling",x_val,y_val,random_search_linear,themes)
# Out:
# Best Score: 0.3212
# Random Oversampling Train Accuracy: 41.0448%
# [5. 6. 3. 5. 2. 3. 6. 5. 6. 6. 6. 6. 6. 6.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# Random Oversampling Validation Accuracy: 21.43%
# Random Oversampling F1-score: 0.18
# Random Oversampling Precision Score: 0.22
# Random Oversampling Recall Score: 0.21
# Random Oversampling ROC-AUC Score: 0.50
# Random Oversampling ROC-AUC Score: 0.75
# Random Oversampling ROC-AUC Score: 0.71
# Random Oversampling ROC-AUC Score: 0.50
# Random Oversampling ROC-AUC Score: 0.36
# Random Oversampling ROC-AUC Score: 0.73
# (21.428571428571427, 0.18253968253968253)

# %%
    print_res_6_way("SMOTE",x_smote,y_smote,random_search_linear,themes)
    test_res_6_way("SMOTE",x_val,y_val,random_search_linear,themes)
# Out:
# Best Score: 0.3435
# penalty => l2
# multi_class => ovr
# max_iter => 600
# loss => squared_hinge
# fit_intercept => False
# dual => False
# C => 0.31257158496882353
# Splits: 10
# SMOTE Train Accuracy: 42.7861%
# [6. 6. 2. 5. 4. 3. 6. 6. 6. 6. 6. 6. 6. 6.]
# [1. 1. 1. 2. 2. 3. 3. 4. 4. 4. 5. 5. 5. 6.]
# SMOTE Validation Accuracy: 14.29%
# SMOTE F1-score: 0.11
# SMOTE Precision Score: 0.15
# SMOTE Recall Score: 0.14
# SMOTE ROC-AUC Score: 0.50
# SMOTE ROC-AUC Score: 0.46
# SMOTE ROC-AUC Score: 0.75
# SMOTE ROC-AUC Score: 0.45
# SMOTE ROC-AUC Score: 0.45
# SMOTE ROC-AUC Score: 0.65
# (14.285714285714285, 0.10822510822510822)
